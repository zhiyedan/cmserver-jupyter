# %%
from sklearn.feature_selection import SelectKBest
from scipy.stats import pearsonr

#选择K个最好的特征，返回选择特征后的数据
#第一个参数为计算评估特征是否好的函数，该函数输入特征矩阵和目标向量，输出二元组（评分，P值）的数组，数组第i项为第i个特征的评分和P值。在此定义为计算相关系数
#参数k为选择的特征个数
SelectKBest(lambda X, Y: array(map(lambda x:pearsonr(x, Y), X.T)).T, k=2).fit_transform(iris.data, iris.target)# 汉诺塔
def move(n, a, b, c):
    if n == 1:
        print(a,'->',c)
    else:
        move(n-1, a, c, b)
        move(1, a, b, c)
        move(n-1, b, a, c)

move(4,'a','b','c')
# Out:
# ('a', '->', 'b')
# ('a', '->', 'c')
# ('b', '->', 'c')
# ('a', '->', 'b')
# ('c', '->', 'a')
# ('c', '->', 'b')
# ('a', '->', 'b')
# ('a', '->', 'c')
# ('b', '->', 'c')
# ('b', '->', 'a')
# ('c', '->', 'a')
# ('b', '->', 'c')
# ('a', '->', 'b')
# ('a', '->', 'c')
# ('b', '->', 'c')

# %%
import pandas as pd
import numpy as np
data = {'col1':np.array([1,2,6,4],dtype='int64'),
       'col2':np.array([3,4,3,7],dtype='int64')}
data1 = pd.DataFrame(data)
data1 = data1.reindex([1,2,3,4])

# %%
data1.dtypes
# Out:
# col1    float64
# col2    float64
# dtype: object

# %%
from sklearn.preprocessing import Imputer
Imputer(strategy='most_frequent').fit(data1)
# Out:
# Imputer(axis=0, copy=True, missing_values='NaN', strategy='most_frequent',
#     verbose=0)

# %%
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectKBest
from scipy.stats import pearsonr
iris = load_iris()
#选择K个最好的特征，返回选择特征后的数据
#第一个参数为计算评估特征是否好的函数，该函数输入特征矩阵和目标向量，输出二元组（评分，P值）的数组，数组第i项为第i个特征的评分和P值。在此定义为计算相关系数
#参数k为选择的特征个数
# SelectKBest(lambda X, Y: array(map(lambda x:pearsonr(x, Y), X.T)).T, k=2).fit_transform(iris.data, iris.target)

# %%
pearsonr(iris.data,iris.target)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-e3277dd0a2d6> in <module>()
# ----> 1 pearsonr(iris.data,iris.target)
#
# /home/zhiyedan/anaconda2/lib/python2.7/site-packages/scipy/stats/stats.pyc in pearsonr(x, y)
#    3017     my = y.mean()
#    3018     xm, ym = x - mx, y - my
# -> 3019     r_num = np.add.reduce(xm * ym)
#    3020     r_den = np.sqrt(_sum_of_squares(xm) * _sum_of_squares(ym))
#    3021     r = r_num / r_den
#
# ValueError: operands could not be broadcast together with shapes (150,4) (150,)

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

#递归特征消除法，返回特征选择后的数据
#参数estimator为基模型
#参数n_features_to_select为选择的特征个数
a = RFE(estimator=LogisticRegression(), n_features_to_select=2).fit_transform(iris.data, iris.target)
# Out:
# array([[ 3.5,  0.2],
#        [ 3. ,  0.2],
#        [ 3.2,  0.2],
#        [ 3.1,  0.2],
#        [ 3.6,  0.2],
#        [ 3.9,  0.4],
#        [ 3.4,  0.3],
#        [ 3.4,  0.2],
#        [ 2.9,  0.2],
#        [ 3.1,  0.1],
#        [ 3.7,  0.2],
#        [ 3.4,  0.2],
#        [ 3. ,  0.1],
#        [ 3. ,  0.1],
#        [ 4. ,  0.2],
#        [ 4.4,  0.4],
#        [ 3.9,  0.4],
#        [ 3.5,  0.3],
#        [ 3.8,  0.3],
#        [ 3.8,  0.3],
#        [ 3.4,  0.2],
#        [ 3.7,  0.4],
#        [ 3.6,  0.2],
#        [ 3.3,  0.5],
#        [ 3.4,  0.2],
#        [ 3. ,  0.2],
#        [ 3.4,  0.4],
#        [ 3.5,  0.2],
#        [ 3.4,  0.2],
#        [ 3.2,  0.2],
#        [ 3.1,  0.2],
#        [ 3.4,  0.4],
#        [ 4.1,  0.1],
#        [ 4.2,  0.2],
#        [ 3.1,  0.1],
#        [ 3.2,  0.2],
#        [ 3.5,  0.2],
#        [ 3.1,  0.1],
#        [ 3. ,  0.2],
#        [ 3.4,  0.2],
#        [ 3.5,  0.3],
#        [ 2.3,  0.3],
#        [ 3.2,  0.2],
#        [ 3.5,  0.6],
#        [ 3.8,  0.4],
#        [ 3. ,  0.3],
#        [ 3.8,  0.2],
#        [ 3.2,  0.2],
#        [ 3.7,  0.2],
#        [ 3.3,  0.2],
#        [ 3.2,  1.4],
#        [ 3.2,  1.5],
#        [ 3.1,  1.5],
#        [ 2.3,  1.3],
#        [ 2.8,  1.5],
#        [ 2.8,  1.3],
#        [ 3.3,  1.6],
#        [ 2.4,  1. ],
#        [ 2.9,  1.3],
#        [ 2.7,  1.4],
#        [ 2. ,  1. ],
#        [ 3. ,  1.5],
#        [ 2.2,  1. ],
#        [ 2.9,  1.4],
#        [ 2.9,  1.3],
#        [ 3.1,  1.4],
#        [ 3. ,  1.5],
#        [ 2.7,  1. ],
#        [ 2.2,  1.5],
#        [ 2.5,  1.1],
#        [ 3.2,  1.8],
#        [ 2.8,  1.3],
#        [ 2.5,  1.5],
#        [ 2.8,  1.2],
#        [ 2.9,  1.3],
#        [ 3. ,  1.4],
#        [ 2.8,  1.4],
#        [ 3. ,  1.7],
#        [ 2.9,  1.5],
#        [ 2.6,  1. ],
#        [ 2.4,  1.1],
#        [ 2.4,  1. ],
#        [ 2.7,  1.2],
#        [ 2.7,  1.6],
#        [ 3. ,  1.5],
#        [ 3.4,  1.6],
#        [ 3.1,  1.5],
#        [ 2.3,  1.3],
#        [ 3. ,  1.3],
#        [ 2.5,  1.3],
#        [ 2.6,  1.2],
#        [ 3. ,  1.4],
#        [ 2.6,  1.2],
#        [ 2.3,  1. ],
#        [ 2.7,  1.3],
#        [ 3. ,  1.2],
#        [ 2.9,  1.3],
#        [ 2.9,  1.3],
#        [ 2.5,  1.1],
#        [ 2.8,  1.3],
#        [ 3.3,  2.5],
#        [ 2.7,  1.9],
#        [ 3. ,  2.1],
#        [ 2.9,  1.8],
#        [ 3. ,  2.2],
#        [ 3. ,  2.1],
#        [ 2.5,  1.7],
#        [ 2.9,  1.8],
#        [ 2.5,  1.8],
#        [ 3.6,  2.5],
#        [ 3.2,  2. ],
#        [ 2.7,  1.9],
#        [ 3. ,  2.1],
#        [ 2.5,  2. ],
#        [ 2.8,  2.4],
#        [ 3.2,  2.3],
#        [ 3. ,  1.8],
#        [ 3.8,  2.2],
#        [ 2.6,  2.3],
#        [ 2.2,  1.5],
#        [ 3.2,  2.3],
#        [ 2.8,  2. ],
#        [ 2.8,  2. ],
#        [ 2.7,  1.8],
#        [ 3.3,  2.1],
#        [ 3.2,  1.8],
#        [ 2.8,  1.8],
#        [ 3. ,  1.8],
#        [ 2.8,  2.1],
#        [ 3. ,  1.6],
#        [ 2.8,  1.9],
#        [ 3.8,  2. ],
#        [ 2.8,  2.2],
#        [ 2.8,  1.5],
#        [ 2.6,  1.4],
#        [ 3. ,  2.3],
#        [ 3.4,  2.4],
#        [ 3.1,  1.8],
#        [ 3. ,  1.8],
#        [ 3.1,  2.1],
#        [ 3.1,  2.4],
#        [ 3.1,  2.3],
#        [ 2.7,  1.9],
#        [ 3.2,  2.3],
#        [ 3.3,  2.5],
#        [ 3. ,  2.3],
#        [ 2.5,  1.9],
#        [ 3. ,  2. ],
#        [ 3.4,  2.3],
#        [ 3. ,  1.8]])

# %%
iris.data
# Out:
# array([[ 5.1,  3.5,  1.4,  0.2],
#        [ 4.9,  3. ,  1.4,  0.2],
#        [ 4.7,  3.2,  1.3,  0.2],
#        [ 4.6,  3.1,  1.5,  0.2],
#        [ 5. ,  3.6,  1.4,  0.2],
#        [ 5.4,  3.9,  1.7,  0.4],
#        [ 4.6,  3.4,  1.4,  0.3],
#        [ 5. ,  3.4,  1.5,  0.2],
#        [ 4.4,  2.9,  1.4,  0.2],
#        [ 4.9,  3.1,  1.5,  0.1],
#        [ 5.4,  3.7,  1.5,  0.2],
#        [ 4.8,  3.4,  1.6,  0.2],
#        [ 4.8,  3. ,  1.4,  0.1],
#        [ 4.3,  3. ,  1.1,  0.1],
#        [ 5.8,  4. ,  1.2,  0.2],
#        [ 5.7,  4.4,  1.5,  0.4],
#        [ 5.4,  3.9,  1.3,  0.4],
#        [ 5.1,  3.5,  1.4,  0.3],
#        [ 5.7,  3.8,  1.7,  0.3],
#        [ 5.1,  3.8,  1.5,  0.3],
#        [ 5.4,  3.4,  1.7,  0.2],
#        [ 5.1,  3.7,  1.5,  0.4],
#        [ 4.6,  3.6,  1. ,  0.2],
#        [ 5.1,  3.3,  1.7,  0.5],
#        [ 4.8,  3.4,  1.9,  0.2],
#        [ 5. ,  3. ,  1.6,  0.2],
#        [ 5. ,  3.4,  1.6,  0.4],
#        [ 5.2,  3.5,  1.5,  0.2],
#        [ 5.2,  3.4,  1.4,  0.2],
#        [ 4.7,  3.2,  1.6,  0.2],
#        [ 4.8,  3.1,  1.6,  0.2],
#        [ 5.4,  3.4,  1.5,  0.4],
#        [ 5.2,  4.1,  1.5,  0.1],
#        [ 5.5,  4.2,  1.4,  0.2],
#        [ 4.9,  3.1,  1.5,  0.1],
#        [ 5. ,  3.2,  1.2,  0.2],
#        [ 5.5,  3.5,  1.3,  0.2],
#        [ 4.9,  3.1,  1.5,  0.1],
#        [ 4.4,  3. ,  1.3,  0.2],
#        [ 5.1,  3.4,  1.5,  0.2],
#        [ 5. ,  3.5,  1.3,  0.3],
#        [ 4.5,  2.3,  1.3,  0.3],
#        [ 4.4,  3.2,  1.3,  0.2],
#        [ 5. ,  3.5,  1.6,  0.6],
#        [ 5.1,  3.8,  1.9,  0.4],
#        [ 4.8,  3. ,  1.4,  0.3],
#        [ 5.1,  3.8,  1.6,  0.2],
#        [ 4.6,  3.2,  1.4,  0.2],
#        [ 5.3,  3.7,  1.5,  0.2],
#        [ 5. ,  3.3,  1.4,  0.2],
#        [ 7. ,  3.2,  4.7,  1.4],
#        [ 6.4,  3.2,  4.5,  1.5],
#        [ 6.9,  3.1,  4.9,  1.5],
#        [ 5.5,  2.3,  4. ,  1.3],
#        [ 6.5,  2.8,  4.6,  1.5],
#        [ 5.7,  2.8,  4.5,  1.3],
#        [ 6.3,  3.3,  4.7,  1.6],
#        [ 4.9,  2.4,  3.3,  1. ],
#        [ 6.6,  2.9,  4.6,  1.3],
#        [ 5.2,  2.7,  3.9,  1.4],
#        [ 5. ,  2. ,  3.5,  1. ],
#        [ 5.9,  3. ,  4.2,  1.5],
#        [ 6. ,  2.2,  4. ,  1. ],
#        [ 6.1,  2.9,  4.7,  1.4],
#        [ 5.6,  2.9,  3.6,  1.3],
#        [ 6.7,  3.1,  4.4,  1.4],
#        [ 5.6,  3. ,  4.5,  1.5],
#        [ 5.8,  2.7,  4.1,  1. ],
#        [ 6.2,  2.2,  4.5,  1.5],
#        [ 5.6,  2.5,  3.9,  1.1],
#        [ 5.9,  3.2,  4.8,  1.8],
#        [ 6.1,  2.8,  4. ,  1.3],
#        [ 6.3,  2.5,  4.9,  1.5],
#        [ 6.1,  2.8,  4.7,  1.2],
#        [ 6.4,  2.9,  4.3,  1.3],
#        [ 6.6,  3. ,  4.4,  1.4],
#        [ 6.8,  2.8,  4.8,  1.4],
#        [ 6.7,  3. ,  5. ,  1.7],
#        [ 6. ,  2.9,  4.5,  1.5],
#        [ 5.7,  2.6,  3.5,  1. ],
#        [ 5.5,  2.4,  3.8,  1.1],
#        [ 5.5,  2.4,  3.7,  1. ],
#        [ 5.8,  2.7,  3.9,  1.2],
#        [ 6. ,  2.7,  5.1,  1.6],
#        [ 5.4,  3. ,  4.5,  1.5],
#        [ 6. ,  3.4,  4.5,  1.6],
#        [ 6.7,  3.1,  4.7,  1.5],
#        [ 6.3,  2.3,  4.4,  1.3],
#        [ 5.6,  3. ,  4.1,  1.3],
#        [ 5.5,  2.5,  4. ,  1.3],
#        [ 5.5,  2.6,  4.4,  1.2],
#        [ 6.1,  3. ,  4.6,  1.4],
#        [ 5.8,  2.6,  4. ,  1.2],
#        [ 5. ,  2.3,  3.3,  1. ],
#        [ 5.6,  2.7,  4.2,  1.3],
#        [ 5.7,  3. ,  4.2,  1.2],
#        [ 5.7,  2.9,  4.2,  1.3],
#        [ 6.2,  2.9,  4.3,  1.3],
#        [ 5.1,  2.5,  3. ,  1.1],
#        [ 5.7,  2.8,  4.1,  1.3],
#        [ 6.3,  3.3,  6. ,  2.5],
#        [ 5.8,  2.7,  5.1,  1.9],
#        [ 7.1,  3. ,  5.9,  2.1],
#        [ 6.3,  2.9,  5.6,  1.8],
#        [ 6.5,  3. ,  5.8,  2.2],
#        [ 7.6,  3. ,  6.6,  2.1],
#        [ 4.9,  2.5,  4.5,  1.7],
#        [ 7.3,  2.9,  6.3,  1.8],
#        [ 6.7,  2.5,  5.8,  1.8],
#        [ 7.2,  3.6,  6.1,  2.5],
#        [ 6.5,  3.2,  5.1,  2. ],
#        [ 6.4,  2.7,  5.3,  1.9],
#        [ 6.8,  3. ,  5.5,  2.1],
#        [ 5.7,  2.5,  5. ,  2. ],
#        [ 5.8,  2.8,  5.1,  2.4],
#        [ 6.4,  3.2,  5.3,  2.3],
#        [ 6.5,  3. ,  5.5,  1.8],
#        [ 7.7,  3.8,  6.7,  2.2],
#        [ 7.7,  2.6,  6.9,  2.3],
#        [ 6. ,  2.2,  5. ,  1.5],
#        [ 6.9,  3.2,  5.7,  2.3],
#        [ 5.6,  2.8,  4.9,  2. ],
#        [ 7.7,  2.8,  6.7,  2. ],
#        [ 6.3,  2.7,  4.9,  1.8],
#        [ 6.7,  3.3,  5.7,  2.1],
#        [ 7.2,  3.2,  6. ,  1.8],
#        [ 6.2,  2.8,  4.8,  1.8],
#        [ 6.1,  3. ,  4.9,  1.8],
#        [ 6.4,  2.8,  5.6,  2.1],
#        [ 7.2,  3. ,  5.8,  1.6],
#        [ 7.4,  2.8,  6.1,  1.9],
#        [ 7.9,  3.8,  6.4,  2. ],
#        [ 6.4,  2.8,  5.6,  2.2],
#        [ 6.3,  2.8,  5.1,  1.5],
#        [ 6.1,  2.6,  5.6,  1.4],
#        [ 7.7,  3. ,  6.1,  2.3],
#        [ 6.3,  3.4,  5.6,  2.4],
#        [ 6.4,  3.1,  5.5,  1.8],
#        [ 6. ,  3. ,  4.8,  1.8],
#        [ 6.9,  3.1,  5.4,  2.1],
#        [ 6.7,  3.1,  5.6,  2.4],
#        [ 6.9,  3.1,  5.1,  2.3],
#        [ 5.8,  2.7,  5.1,  1.9],
#        [ 6.8,  3.2,  5.9,  2.3],
#        [ 6.7,  3.3,  5.7,  2.5],
#        [ 6.7,  3. ,  5.2,  2.3],
#        [ 6.3,  2.5,  5. ,  1.9],
#        [ 6.5,  3. ,  5.2,  2. ],
#        [ 6.2,  3.4,  5.4,  2.3],
#        [ 5.9,  3. ,  5.1,  1.8]])

# %%
from sklearn.lda import LDA
LDA(n_component=2).fit_transform(iris.data, iris.target)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-65-f83cb097b084> in <module>()
# ----> 1 from sklearn.lda import LDA
#       2 LDA(n_component=2).fit_transform(iris.data, iris.target)
#
# ImportError: No module named lda

# %%
from sklearn.feature_selection import SelectFromModel
SelectFromModel(LogisticRegression(penalty="l1", C=0.1)).fit_transform(iris.data, iris.target)
# Out:
# array([[ 5.1,  3.5,  1.4],
#        [ 4.9,  3. ,  1.4],
#        [ 4.7,  3.2,  1.3],
#        [ 4.6,  3.1,  1.5],
#        [ 5. ,  3.6,  1.4],
#        [ 5.4,  3.9,  1.7],
#        [ 4.6,  3.4,  1.4],
#        [ 5. ,  3.4,  1.5],
#        [ 4.4,  2.9,  1.4],
#        [ 4.9,  3.1,  1.5],
#        [ 5.4,  3.7,  1.5],
#        [ 4.8,  3.4,  1.6],
#        [ 4.8,  3. ,  1.4],
#        [ 4.3,  3. ,  1.1],
#        [ 5.8,  4. ,  1.2],
#        [ 5.7,  4.4,  1.5],
#        [ 5.4,  3.9,  1.3],
#        [ 5.1,  3.5,  1.4],
#        [ 5.7,  3.8,  1.7],
#        [ 5.1,  3.8,  1.5],
#        [ 5.4,  3.4,  1.7],
#        [ 5.1,  3.7,  1.5],
#        [ 4.6,  3.6,  1. ],
#        [ 5.1,  3.3,  1.7],
#        [ 4.8,  3.4,  1.9],
#        [ 5. ,  3. ,  1.6],
#        [ 5. ,  3.4,  1.6],
#        [ 5.2,  3.5,  1.5],
#        [ 5.2,  3.4,  1.4],
#        [ 4.7,  3.2,  1.6],
#        [ 4.8,  3.1,  1.6],
#        [ 5.4,  3.4,  1.5],
#        [ 5.2,  4.1,  1.5],
#        [ 5.5,  4.2,  1.4],
#        [ 4.9,  3.1,  1.5],
#        [ 5. ,  3.2,  1.2],
#        [ 5.5,  3.5,  1.3],
#        [ 4.9,  3.1,  1.5],
#        [ 4.4,  3. ,  1.3],
#        [ 5.1,  3.4,  1.5],
#        [ 5. ,  3.5,  1.3],
#        [ 4.5,  2.3,  1.3],
#        [ 4.4,  3.2,  1.3],
#        [ 5. ,  3.5,  1.6],
#        [ 5.1,  3.8,  1.9],
#        [ 4.8,  3. ,  1.4],
#        [ 5.1,  3.8,  1.6],
#        [ 4.6,  3.2,  1.4],
#        [ 5.3,  3.7,  1.5],
#        [ 5. ,  3.3,  1.4],
#        [ 7. ,  3.2,  4.7],
#        [ 6.4,  3.2,  4.5],
#        [ 6.9,  3.1,  4.9],
#        [ 5.5,  2.3,  4. ],
#        [ 6.5,  2.8,  4.6],
#        [ 5.7,  2.8,  4.5],
#        [ 6.3,  3.3,  4.7],
#        [ 4.9,  2.4,  3.3],
#        [ 6.6,  2.9,  4.6],
#        [ 5.2,  2.7,  3.9],
#        [ 5. ,  2. ,  3.5],
#        [ 5.9,  3. ,  4.2],
#        [ 6. ,  2.2,  4. ],
#        [ 6.1,  2.9,  4.7],
#        [ 5.6,  2.9,  3.6],
#        [ 6.7,  3.1,  4.4],
#        [ 5.6,  3. ,  4.5],
#        [ 5.8,  2.7,  4.1],
#        [ 6.2,  2.2,  4.5],
#        [ 5.6,  2.5,  3.9],
#        [ 5.9,  3.2,  4.8],
#        [ 6.1,  2.8,  4. ],
#        [ 6.3,  2.5,  4.9],
#        [ 6.1,  2.8,  4.7],
#        [ 6.4,  2.9,  4.3],
#        [ 6.6,  3. ,  4.4],
#        [ 6.8,  2.8,  4.8],
#        [ 6.7,  3. ,  5. ],
#        [ 6. ,  2.9,  4.5],
#        [ 5.7,  2.6,  3.5],
#        [ 5.5,  2.4,  3.8],
#        [ 5.5,  2.4,  3.7],
#        [ 5.8,  2.7,  3.9],
#        [ 6. ,  2.7,  5.1],
#        [ 5.4,  3. ,  4.5],
#        [ 6. ,  3.4,  4.5],
#        [ 6.7,  3.1,  4.7],
#        [ 6.3,  2.3,  4.4],
#        [ 5.6,  3. ,  4.1],
#        [ 5.5,  2.5,  4. ],
#        [ 5.5,  2.6,  4.4],
#        [ 6.1,  3. ,  4.6],
#        [ 5.8,  2.6,  4. ],
#        [ 5. ,  2.3,  3.3],
#        [ 5.6,  2.7,  4.2],
#        [ 5.7,  3. ,  4.2],
#        [ 5.7,  2.9,  4.2],
#        [ 6.2,  2.9,  4.3],
#        [ 5.1,  2.5,  3. ],
#        [ 5.7,  2.8,  4.1],
#        [ 6.3,  3.3,  6. ],
#        [ 5.8,  2.7,  5.1],
#        [ 7.1,  3. ,  5.9],
#        [ 6.3,  2.9,  5.6],
#        [ 6.5,  3. ,  5.8],
#        [ 7.6,  3. ,  6.6],
#        [ 4.9,  2.5,  4.5],
#        [ 7.3,  2.9,  6.3],
#        [ 6.7,  2.5,  5.8],
#        [ 7.2,  3.6,  6.1],
#        [ 6.5,  3.2,  5.1],
#        [ 6.4,  2.7,  5.3],
#        [ 6.8,  3. ,  5.5],
#        [ 5.7,  2.5,  5. ],
#        [ 5.8,  2.8,  5.1],
#        [ 6.4,  3.2,  5.3],
#        [ 6.5,  3. ,  5.5],
#        [ 7.7,  3.8,  6.7],
#        [ 7.7,  2.6,  6.9],
#        [ 6. ,  2.2,  5. ],
#        [ 6.9,  3.2,  5.7],
#        [ 5.6,  2.8,  4.9],
#        [ 7.7,  2.8,  6.7],
#        [ 6.3,  2.7,  4.9],
#        [ 6.7,  3.3,  5.7],
#        [ 7.2,  3.2,  6. ],
#        [ 6.2,  2.8,  4.8],
#        [ 6.1,  3. ,  4.9],
#        [ 6.4,  2.8,  5.6],
#        [ 7.2,  3. ,  5.8],
#        [ 7.4,  2.8,  6.1],
#        [ 7.9,  3.8,  6.4],
#        [ 6.4,  2.8,  5.6],
#        [ 6.3,  2.8,  5.1],
#        [ 6.1,  2.6,  5.6],
#        [ 7.7,  3. ,  6.1],
#        [ 6.3,  3.4,  5.6],
#        [ 6.4,  3.1,  5.5],
#        [ 6. ,  3. ,  4.8],
#        [ 6.9,  3.1,  5.4],
#        [ 6.7,  3.1,  5.6],
#        [ 6.9,  3.1,  5.1],
#        [ 5.8,  2.7,  5.1],
#        [ 6.8,  3.2,  5.9],
#        [ 6.7,  3.3,  5.7],
#        [ 6.7,  3. ,  5.2],
#        [ 6.3,  2.5,  5. ],
#        [ 6.5,  3. ,  5.2],
#        [ 6.2,  3.4,  5.4],
#        [ 5.9,  3. ,  5.1]])

# %%
from sklearn.ensemble import GradientBoostingClassifier
SelectFromModel(GradientBoostingClassifier()).fit_transform(iris.data,iris.target)
# Out:
# array([[ 1.4,  0.2],
#        [ 1.4,  0.2],
#        [ 1.3,  0.2],
#        [ 1.5,  0.2],
#        [ 1.4,  0.2],
#        [ 1.7,  0.4],
#        [ 1.4,  0.3],
#        [ 1.5,  0.2],
#        [ 1.4,  0.2],
#        [ 1.5,  0.1],
#        [ 1.5,  0.2],
#        [ 1.6,  0.2],
#        [ 1.4,  0.1],
#        [ 1.1,  0.1],
#        [ 1.2,  0.2],
#        [ 1.5,  0.4],
#        [ 1.3,  0.4],
#        [ 1.4,  0.3],
#        [ 1.7,  0.3],
#        [ 1.5,  0.3],
#        [ 1.7,  0.2],
#        [ 1.5,  0.4],
#        [ 1. ,  0.2],
#        [ 1.7,  0.5],
#        [ 1.9,  0.2],
#        [ 1.6,  0.2],
#        [ 1.6,  0.4],
#        [ 1.5,  0.2],
#        [ 1.4,  0.2],
#        [ 1.6,  0.2],
#        [ 1.6,  0.2],
#        [ 1.5,  0.4],
#        [ 1.5,  0.1],
#        [ 1.4,  0.2],
#        [ 1.5,  0.1],
#        [ 1.2,  0.2],
#        [ 1.3,  0.2],
#        [ 1.5,  0.1],
#        [ 1.3,  0.2],
#        [ 1.5,  0.2],
#        [ 1.3,  0.3],
#        [ 1.3,  0.3],
#        [ 1.3,  0.2],
#        [ 1.6,  0.6],
#        [ 1.9,  0.4],
#        [ 1.4,  0.3],
#        [ 1.6,  0.2],
#        [ 1.4,  0.2],
#        [ 1.5,  0.2],
#        [ 1.4,  0.2],
#        [ 4.7,  1.4],
#        [ 4.5,  1.5],
#        [ 4.9,  1.5],
#        [ 4. ,  1.3],
#        [ 4.6,  1.5],
#        [ 4.5,  1.3],
#        [ 4.7,  1.6],
#        [ 3.3,  1. ],
#        [ 4.6,  1.3],
#        [ 3.9,  1.4],
#        [ 3.5,  1. ],
#        [ 4.2,  1.5],
#        [ 4. ,  1. ],
#        [ 4.7,  1.4],
#        [ 3.6,  1.3],
#        [ 4.4,  1.4],
#        [ 4.5,  1.5],
#        [ 4.1,  1. ],
#        [ 4.5,  1.5],
#        [ 3.9,  1.1],
#        [ 4.8,  1.8],
#        [ 4. ,  1.3],
#        [ 4.9,  1.5],
#        [ 4.7,  1.2],
#        [ 4.3,  1.3],
#        [ 4.4,  1.4],
#        [ 4.8,  1.4],
#        [ 5. ,  1.7],
#        [ 4.5,  1.5],
#        [ 3.5,  1. ],
#        [ 3.8,  1.1],
#        [ 3.7,  1. ],
#        [ 3.9,  1.2],
#        [ 5.1,  1.6],
#        [ 4.5,  1.5],
#        [ 4.5,  1.6],
#        [ 4.7,  1.5],
#        [ 4.4,  1.3],
#        [ 4.1,  1.3],
#        [ 4. ,  1.3],
#        [ 4.4,  1.2],
#        [ 4.6,  1.4],
#        [ 4. ,  1.2],
#        [ 3.3,  1. ],
#        [ 4.2,  1.3],
#        [ 4.2,  1.2],
#        [ 4.2,  1.3],
#        [ 4.3,  1.3],
#        [ 3. ,  1.1],
#        [ 4.1,  1.3],
#        [ 6. ,  2.5],
#        [ 5.1,  1.9],
#        [ 5.9,  2.1],
#        [ 5.6,  1.8],
#        [ 5.8,  2.2],
#        [ 6.6,  2.1],
#        [ 4.5,  1.7],
#        [ 6.3,  1.8],
#        [ 5.8,  1.8],
#        [ 6.1,  2.5],
#        [ 5.1,  2. ],
#        [ 5.3,  1.9],
#        [ 5.5,  2.1],
#        [ 5. ,  2. ],
#        [ 5.1,  2.4],
#        [ 5.3,  2.3],
#        [ 5.5,  1.8],
#        [ 6.7,  2.2],
#        [ 6.9,  2.3],
#        [ 5. ,  1.5],
#        [ 5.7,  2.3],
#        [ 4.9,  2. ],
#        [ 6.7,  2. ],
#        [ 4.9,  1.8],
#        [ 5.7,  2.1],
#        [ 6. ,  1.8],
#        [ 4.8,  1.8],
#        [ 4.9,  1.8],
#        [ 5.6,  2.1],
#        [ 5.8,  1.6],
#        [ 6.1,  1.9],
#        [ 6.4,  2. ],
#        [ 5.6,  2.2],
#        [ 5.1,  1.5],
#        [ 5.6,  1.4],
#        [ 6.1,  2.3],
#        [ 5.6,  2.4],
#        [ 5.5,  1.8],
#        [ 4.8,  1.8],
#        [ 5.4,  2.1],
#        [ 5.6,  2.4],
#        [ 5.1,  2.3],
#        [ 5.1,  1.9],
#        [ 5.9,  2.3],
#        [ 5.7,  2.5],
#        [ 5.2,  2.3],
#        [ 5. ,  1.9],
#        [ 5.2,  2. ],
#        [ 5.4,  2.3],
#        [ 5.1,  1.8]])
