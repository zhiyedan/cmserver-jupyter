# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def parser(time_data):
    return pd.datetime.strptime('2017-'+time_data,'%Y-%d-%m %H:%M:%S')
#     return pd.to_datetime(time_data)
data = pd.read_csv('../data/cm_monitor.csv',index_col=0, parse_dates=[0], date_parser=parser)

# %%
data.head()
# Out:
#                         usr    sys     idl    wai  hiq    siq          used  \
# date/time
# 2017-11-24 17:39:34   0.773  0.213  98.962  0.047  0.0  0.006  1.530511e+10
# 2017-11-24 17:40:34  13.887  5.384  80.599  0.109  0.0  0.021  1.531253e+10
# 2017-11-24 17:41:34  13.708  5.095  80.951  0.221  0.0  0.024  1.535545e+10
# 2017-11-24 17:42:34  13.721  5.415  80.693  0.146  0.0  0.025  1.533875e+10
# 2017-11-24 17:43:34  14.302  5.456  80.057  0.163  0.0  0.022  1.533918e+10
#
#                             buff          cach          free       recv  \
# date/time
# 2017-11-24 17:39:34  429469696.0  2.207573e+10  1.275072e+10      0.000
# 2017-11-24 17:40:34  429490176.0  2.208113e+10  1.273788e+10  19003.717
# 2017-11-24 17:41:34  429527040.0  2.207602e+10  1.270003e+10  19736.900
# 2017-11-24 17:42:34  429547520.0  2.207249e+10  1.272024e+10  17881.933
# 2017-11-24 17:43:34  429563904.0  2.206883e+10  1.272345e+10  19156.683
#
#                           send   read    writ  \
# date/time
# 2017-11-24 17:39:34      0.000  0.035   6.322
# 2017-11-24 17:40:34  13556.350  0.000  11.950
# 2017-11-24 17:41:34  14056.183  0.000  22.567
# 2017-11-24 17:42:34  13445.050  0.000  13.267
# 2017-11-24 17:43:34  13395.767  0.000  17.733
#
#                                                            cpu process  \
# date/time
# 2017-11-24 17:39:34                                          java / 0%
# 2017-11-24 17:40:34  kernel-963d1b1e-b11a-4d9a-b233-6ec63885d9f4.js...
# 2017-11-24 17:41:34  kernel-963d1b1e-b11a-4d9a-b233-6ec63885d9f4.js...
# 2017-11-24 17:42:34  kernel-963d1b1e-b11a-4d9a-b233-6ec63885d9f4.js...
# 2017-11-24 17:43:34  kernel-963d1b1e-b11a-4d9a-b233-6ec63885d9f4.js...
#
#                          memory process
# date/time
# 2017-11-24 17:39:34  java / 2682208256%
# 2017-11-24 17:40:34  java / 2682134528%
# 2017-11-24 17:41:34  java / 2681978880%
# 2017-11-24 17:42:34  java / 2681962496%
# 2017-11-24 17:43:34  java / 2682908672%

# %%
# data.idl.plot()
# data.free.plot()
# data.recv.plot()
data.used.plot()
# data.send.plot()
# data.writ.plot()
plt.gcf().set_size_inches(18,8)
plt.show()
